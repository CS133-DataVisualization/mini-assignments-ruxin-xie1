#
#     Strategy
# 0   6.433333
# 1   7.175000
# 2   7.400000
# 3   7.116667
# 4   7.900000
# 5   6.900000
# 6   6.644737
# 7   6.566667
# 8   7.310207
# 9   6.496875
# 10  7.238889
# 11  7.355172
# 12  6.566667
# 13  6.550000
# 14  8.900000
# 15  6.975000
# 16  7.542857
# 17  7.313333
# 18  7.112245
# 19  8.500000
# 20  7.534921

# %% [markdown]
# ## Problem 1 - (1 point)
# Use the dataframe ign_scores and write one line of code to determine the highest score received by any kind of games on the Wii platform?

# %%
## Your code here
highest_wii_score = ign_scores[ign_scores['Platform'] == 'Wii'].drop('Platform', axis=1).max(axis=1).values[0]
print("The highest score received by any kind of game on the Wii platform is:", highest_wii_score)
# Out:
# The highest score received by any kind of game on the Wii platform is: 7.410344827586206

# %% [markdown]
# ## Problem 2 - (1 point)
# Use the dataframe `ign_scores` to determine which genre has the lowest score for the `PlayStation Vita` platform.

# %%
## Your code here
lowest_vita_genre = ign_scores[ign_scores['Platform'] == 'PlayStation Vita'].drop('Platform', axis=1).idxmin(axis=1).values[0]
print("The genre with the lowest score on PlayStation Vita is:", lowest_vita_genre)
# Out:
# The genre with the lowest score on PlayStation Vita is: Simulation

# %% [markdown]
# ## Problem 3 -  (2 points)
# Your instructor's favorite video game has been Mario Kart Wii, a racing game released for the Wii platform in 2008. And, IGN agrees with her that it is a great game -- their rating for this game is a whopping 8.9! Inspired by the success of this game, your instructor is considering creating your very own racing game for the Wii platform. Perform the following analyses to help her determine which platform she should focus on.
#
# 1. Create a bar chart that shows the score for *Racing* games, for each platform. Your chart should have one bar for each platform. Provide a meaningful title to the plot.
#
# 2. Based on the bar chart, do you expect a racing game for the **Wii** platform to receive a high rating?  If not, use the pandas to find out from the dataframe `ign_scores` which gaming platform is the best for racing game?

# %%
# (1 point)
# Set the width and height of the figure
# Your code here . . .
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

ign_scores.plot(kind='bar', x='Platform', y='Racing', legend=False)

plt.title('Racing Game Scores by Platform')
plt.xlabel('Platform')
plt.ylabel('Racing Game Score')

plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
## (1 point)
## Use ign_scores to determine which gaming platform is the best
## for racing game.

## Your code here . . .
best_racing_platform = ign_scores[['Platform', 'Racing']].sort_values(by='Racing', ascending=False).iloc[0]
print("The best platform for racing games is:", best_racing_platform['Platform'], "with a score of:", best_racing_platform['Racing'])
# Out:
# The best platform for racing games is: Xbox One with a score of: 8.163636363636364

# %% [markdown]
# #### Problem 4 - (2 points)
# Since your instructor's gaming interests are pretty broad, you can help her decide to use the IGN scores to determine the choice of genre and platform.
#
# 1. Create a heatmap using the IGN scores by genre and platform and include the scores in the cells of the heatmap.
# 2. Base on the heatmap, which combination of genre and platform receives the highest average ratings?  Which combination receives the lowest average rankings? Write the answers in a markdown cell.

# %%
## Create a heatmap
# Your code here . . .
import seaborn as sns
import matplotlib.pyplot as plt

pivot_table = ign_scores.set_index('Platform')

plt.figure(figsize=(14,8))
sns.heatmap(pivot_table, annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Heatmap of IGN Scores by Platform and Genre")
plt.show()

highest_combination = pivot_table.stack().idxmax()
lowest_combination = pivot_table.stack().idxmin()
print("Highest rated platform-genre combination:", highest_combination)
print("Lowest rated platform-genre combination:", lowest_combination)
# Out:
# Highest rated platform-genre combination: ('PlayStation 4', 'Simulation')
# Lowest rated platform-genre combination: ('Game Boy Color', 'Fighting')

# %% [markdown]
# Highest rated platform-genre combination: ('PlayStation 4', 'Simulation')
# Lowest rated platform-genre combination: ('Game Boy Color', 'Fighting')

# %% [markdown]
# ## Problem 5 - (4 points)
# Use the Pokemon dataset to create a clustermap with color. First, filter the dataframe to only keep data with `Type 1` equals to following values: `Water`, `Normal`, `Grass`, `Bug` and `Psychic`. Annotate the dendrogram using different colors for these five different `Type 1` values. Use `Name` as the index.
#
# pokemon_data is in https://raw.githubusercontent.com/csbfx/advpy122-data/master/Pokemon.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pokemon_data_url = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/Pokemon.csv"
pokemon_data = pd.read_csv(pokemon_data_url)

filtered_pokemon_data = pokemon_data[pokemon_data['Type 1'].isin(['Water', 'Normal', 'Grass', 'Bug', 'Psychic'])]

filtered_pokemon_data.set_index('Name', inplace=True)

stats_columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
filtered_stats_data = filtered_pokemon_data[stats_columns]

type_colors = filtered_pokemon_data['Type 1'].map({
    'Water': 'blue',
    'Normal': 'gray',
    'Grass': 'green',
    'Bug': 'brown',
    'Psychic': 'purple'
})

sns.clustermap(filtered_stats_data, row_colors=type_colors, cmap="viridis", figsize=(10, 8), annot=False)

plt.title("Clustermap of Pokémon Stats (Filtered by Type 1)")
plt.show()
